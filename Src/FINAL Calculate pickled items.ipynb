# %% [markdown]
# This file is used to create and pickle the 'base' graph files and shortest paths so they can be used later

# %%
import pandas as pd
import networkx as nx
import scripts as scr
import fileloader as fl

# %% [markdown]
# First, grabbing the required files using fileloader.py

# %%
graph = fl.get_network()
od = fl.get_OD_LU()
frequency = fl.get_frequency()

# %% [markdown]
# Next, we want to save the 'basegraphs' - unaltered network graphs which have their capacity assigned.

# %%
basegraphs = scr.create_base_graphs(graph, frequency)
# Out:
# Added capacity for timeslot: Morning (0500-0700)
# Added capacity for timeslot: AM Peak (0700-1000)
# Added capacity for timeslot: Inter Peak (1000-1600)
# Added capacity for timeslot: PM Peak (1600-1900)
# Added capacity for timeslot: Evening (1900-2200)
# Added capacity for timeslot: Late (2200-0030)
# Added capacity for timeslot: Night (0030-0300)
# Added capacity for timeslot: Early (0300-0500)

# %% [markdown]
# In certain (late) timeslots, due to very low train frequency, capacity is at 0. This skews results, therefore we iteratively take the average capacity of neighbouring links which sligtly increases average capacity, but allows for better analysis of results.

# %%
def fixCapacity(bgraph, depth):
    depth += 1 #keep track of depth to prevent  
    nocap = [(a, b) for a, b, data in bgraph.edges(data=True) if data['capacity'] == 0] #create a list of edges with no capacity
    for start, end in nocap:
        sneighbors = [n for n in bgraph.neighbors(start)] 
        eneighbors = [n for n in bgraph.neighbors(end)]
        savg = sum([bgraph[s][start]['capacity'] for s in sneighbors])/len(sneighbors) #average of neighbours at start of link
        eavg = sum([bgraph[e][end]['capacity'] for e in eneighbors])/len(sneighbors) #average of neighbours at end of link
        bgraph[start][end]['capacity'] = (savg + eavg)//2
    if depth > 100: #if it doesn't converge at 100 iterations, stop
        print('no solution found')
        return
    if len(nocap) > 0: 
        fixCapacity(bgraph, depth)
    return

for bgraph in basegraphs.values(): 
    fixCapacity(bgraph, 0)

# %% [markdown]
# One of the more 'heavier' calculations is getting the shortest path for the ~68k OD-pairs. Therefore, we also want to save this into a pickle object

# %%
#TODO remove prints
baseshortest = scr.create_shortest_paths(graph, od)
#Saving the base shortestpaths
fl.save_obj(baseshortest, 'baseshortest')
# Out:
# inal 5 LU
# Barbican Heathrow Terminal 5 LU
# Aldgate Heathrow Terminal 5 LU
# Aldgate East Heathrow Terminal 5 LU
# Alperton Heathrow Terminal 5 LU
# Amersham Heathrow Terminal 5 LU
# Angel Heathrow Terminal 5 LU
# Archway Heathrow Terminal 5 LU
# Arnos Grove Heathrow Terminal 5 LU
# Arsenal Heathrow Terminal 5 LU
# Baker Street Heathrow Terminal 5 LU
# Balham LU Heathrow Terminal 5 LU
# Bank and Monument Heathrow Terminal 5 LU
# Barking Heathrow Terminal 5 LU
# Barkingside Heathrow Terminal 5 LU
# Barons Court Heathrow Terminal 5 LU
# Bayswater Heathrow Terminal 5 LU
# Becontree Heathrow Terminal 5 LU
# Belsize Park Heathrow Terminal 5 LU
# Bethnal Green LU Heathrow Terminal 5 LU
# Blackfriars LU Heathrow Terminal 5 LU
# Blackhorse Road Heathrow Terminal 5 LU
# Bond Street Heathrow Terminal 5 LU
# Borough Heathrow Terminal 5 LU
# Boston Manor Heathrow Terminal 5 LU
# Bounds Green Heathrow Terminal 5 LU
# Bow Road Heathrow Terminal 5 LU
# Brent Cross Heathrow Terminal 5 LU
# Bromley-by-Bow Heathrow Terminal 5 LU
# Buckhurst Hill Heathrow Terminal 5 LU
# Burnt Oak Heathrow Terminal 5 LU
# Caledonian Road Heathrow Terminal 5 LU
# Camden Town Heathrow Terminal 5 LU
# Cannon Street LU Heathrow Terminal 5 LU
# Canons Park Heathrow Terminal 5 LU
# Chalfont & Latimer Heathrow Terminal 5 LU
# Chalk Farm Heathrow Terminal 5 LU
# Chancery Lane Heathrow Terminal 5 LU
# Embankment Heathrow Terminal 5 LU
# Chesham Heathrow Terminal 5 LU
# Chiswick Park Heathrow Terminal 5 LU
# Clapham Common Heathrow Terminal 5 LU
# Clapham North Heathrow Terminal 5 LU
# Clapham South Heathrow Terminal 5 LU
# Cockfosters Heathrow Terminal 5 LU
# Colindale Heathrow Terminal 5 LU
# Colliers Wood Heathrow Terminal 5 LU
# Covent Garden Heathrow Terminal 5 LU
# Dagenham East Heathrow Terminal 5 LU
# Dagenham Heathway Heathrow Terminal 5 LU
# Debden Heathrow Terminal 5 LU
# Dollis Hill Heathrow Terminal 5 LU
# Ealing Broadway Heathrow Terminal 5 LU
# Ealing Common Heathrow Terminal 5 LU
# Earl's Court Heathrow Terminal 5 LU
# East Acton Heathrow Terminal 5 LU
# Eastcote Heathrow Terminal 5 LU
# East Finchley Heathrow Terminal 5 LU
# East Ham Heathrow Terminal 5 LU
# East Putney Heathrow Terminal 5 LU
# Edgware Heathrow Terminal 5 LU
# Edgware Road (DIS) Heathrow Terminal 5 LU
# Elephant & Castle LU Heathrow Terminal 5 LU
# Elm Park Heathrow Terminal 5 LU
# Epping Heathrow Terminal 5 LU
# Euston LU Heathrow Terminal 5 LU
# Euston Square Heathrow Terminal 5 LU
# Fairlop Heathrow Terminal 5 LU
# Farringdon Heathrow Terminal 5 LU
# Finchley Central Heathrow Terminal 5 LU
# Finchley Road Heathrow Terminal 5 LU
# Finsbury Park LU Heathrow Terminal 5 LU
# Fulham Broadway Heathrow Terminal 5 LU
# Gants Hill Heathrow Terminal 5 LU
# Gloucester Road Heathrow Terminal 5 LU
# Golders Green Heathrow Terminal 5 LU
# Goldhawk Road Heathrow Terminal 5 LU
# Goodge Street Heathrow Terminal 5 LU
# Grange Hill Heathrow Terminal 5 LU
# Great Portland Street Heathrow Terminal 5 LU
# Greenford Heathrow Terminal 5 LU
# Green Park Heathrow Terminal 5 LU
# Gunnersbury Heathrow Terminal 5 LU
# Hainault Heathrow Terminal 5 LU
# Hammersmith (DIS) Heathrow Terminal 5 LU
# Hampstead Heathrow Terminal 5 LU
# Harlesden Heathrow Terminal 5 LU
# Harrow-on-the-Hill Heathrow Terminal 5 LU
# Wood Lane Heathrow Terminal 5 LU
# Hendon Central Heathrow Terminal 5 LU
# High Barnet Heathrow Terminal 5 LU
# Highbury & Islington Heathrow Terminal 5 LU
# Highgate Heathrow Terminal 5 LU
# High Street Kensington Heathrow Terminal 5 LU
# Hillingdon Heathrow Terminal 5 LU
# Holborn Heathrow Terminal 5 LU
# Holland Park Heathrow Terminal 5 LU
# Holloway Road Heathrow Terminal 5 LU
# Hornchurch Heathrow Terminal 5 LU
# Hounslow Central Heathrow Terminal 5 LU
# Hounslow East Heathrow Terminal 5 LU
# Hounslow West Heathrow Terminal 5 LU
# Hyde Park Corner Heathrow Terminal 5 LU
# Ickenham Heathrow Terminal 5 LU
# Kennington Heathrow Terminal 5 LU
# Kensal Green Heathrow Terminal 5 LU
# Kensington (Olympia) Heathrow Terminal 5 LU
# Kentish Town Heathrow Terminal 5 LU
# Kew Gardens Heathrow Terminal 5 LU
# Kilburn Heathrow Terminal 5 LU
# Kilburn Park Heathrow Terminal 5 LU
# Kingsbury Heathrow Terminal 5 LU
# King's Cross St. Pancras Heathrow Terminal 5 LU
# Knightsbridge Heathrow Terminal 5 LU
# Ladbroke Grove Heathrow Terminal 5 LU
# Lambeth North Heathrow Terminal 5 LU
# Lancaster Gate Heathrow Terminal 5 LU
# Latimer Road Heathrow Terminal 5 LU
# Leicester Square Heathrow Terminal 5 LU
# Leyton Heathrow Terminal 5 LU
# Leytonstone Heathrow Terminal 5 LU
# Liverpool Street LU Heathrow Terminal 5 LU
# London Bridge LU Heathrow Terminal 5 LU
# Loughton Heathrow Terminal 5 LU
# Maida Vale Heathrow Terminal 5 LU
# Manor House Heathrow Terminal 5 LU
# Mansion House Heathrow Terminal 5 LU
# Marble Arch Heathrow Terminal 5 LU
# Marylebone LU Heathrow Terminal 5 LU
# Mile End Heathrow Terminal 5 LU
# Mill Hill East Heathrow Terminal 5 LU
# Moorgate Heathrow Terminal 5 LU
# Moor Park Heathrow Terminal 5 LU
# Morden Heathrow Terminal 5 LU
# Mornington Crescent Heathrow Terminal 5 LU
# Neasden Heathrow Terminal 5 LU
# Newbury Park Heathrow Terminal 5 LU
# North Acton Heathrow Terminal 5 LU
# North Ealing Heathrow Terminal 5 LU
# Northfields Heathrow Terminal 5 LU
# North Harrow Heathrow Terminal 5 LU
# Northwick Park Heathrow Terminal 5 LU
# Northwood Heathrow Terminal 5 LU
# Northwood Hills Heathrow Terminal 5 LU
# Notting Hill Gate Heathrow Terminal 5 LU
# Oakwood Heathrow Terminal 5 LU
# Old Street Heathrow Terminal 5 LU
# Osterley Heathrow Terminal 5 LU
# Oval Heathrow Terminal 5 LU
# Oxford Circus Heathrow Terminal 5 LU
# Paddington TfL Heathrow Terminal 5 LU
# Park Royal Heathrow Terminal 5 LU
# Parsons Green Heathrow Terminal 5 LU
# Perivale Heathrow Terminal 5 LU
# Piccadilly Circus Heathrow Terminal 5 LU
# Pinner Heathrow Terminal 5 LU
# Plaistow Heathrow Terminal 5 LU
# Preston Road Heathrow Terminal 5 LU
# Putney Bridge Heathrow Terminal 5 LU
# Queensbury Heathrow Terminal 5 LU
# Queen's Park Heathrow Terminal 5 LU
# Queensway Heathrow Terminal 5 LU
# Ravenscourt Park Heathrow Terminal 5 LU
# Rayners Lane Heathrow Terminal 5 LU
# Redbridge Heathrow Terminal 5 LU
# Regent's Park Heathrow Terminal 5 LU
# Richmond Heathrow Terminal 5 LU
# Rickmansworth Heathrow Terminal 5 LU
# Roding Valley Heathrow Terminal 5 LU
# Royal Oak Heathrow Terminal 5 LU
# Ruislip Heathrow Terminal 5 LU
# Ruislip Gardens Heathrow Terminal 5 LU
# Ruislip Manor Heathrow Terminal 5 LU
# Russell Square Heathrow Terminal 5 LU
# St. James's Park Heathrow Terminal 5 LU
# St. John's Wood Heathrow Terminal 5 LU
# St. Paul's Heathrow Terminal 5 LU
# Seven Sisters Heathrow Terminal 5 LU
# Shepherd's Bush LU Heathrow Terminal 5 LU
# Sloane Square Heathrow Terminal 5 LU
# Snaresbrook Heathrow Terminal 5 LU
# South Ealing Heathrow Terminal 5 LU
# Southfields Heathrow Terminal 5 LU
# Southgate Heathrow Terminal 5 LU
# South Harrow Heathrow Terminal 5 LU
# South Kensington Heathrow Terminal 5 LU
# South Kenton Heathrow Terminal 5 LU
# South Ruislip Heathrow Terminal 5 LU
# South Wimbledon Heathrow Terminal 5 LU
# South Woodford Heathrow Terminal 5 LU
# Stamford Brook Heathrow Terminal 5 LU
# Stanmore Heathrow Terminal 5 LU
# Stepney Green Heathrow Terminal 5 LU
# Stockwell Heathrow Terminal 5 LU
# Stonebridge Park Heathrow Terminal 5 LU
# Charing Cross LU Heathrow Terminal 5 LU
# Stratford Heathrow Terminal 5 LU
# Sudbury Hill Heathrow Terminal 5 LU
# Sudbury Town Heathrow Terminal 5 LU
# Swiss Cottage Heathrow Terminal 5 LU
# Temple Heathrow Terminal 5 LU
# Tooting Bec Heathrow Terminal 5 LU
# Tooting Broadway Heathrow Terminal 5 LU
# Tottenham Court Road Heathrow Terminal 5 LU
# Tottenham Hale LU Heathrow Terminal 5 LU
# Totteridge & Whetstone Heathrow Terminal 5 LU
# Tower Hill Heathrow Terminal 5 LU
# Tufnell Park Heathrow Terminal 5 LU
# Turnham Green Heathrow Terminal 5 LU
# Turnpike Lane Heathrow Terminal 5 LU
# Upminster Heathrow Terminal 5 LU
# Upminster Bridge Heathrow Terminal 5 LU
# Upney Heathrow Terminal 5 LU
# Upton Park Heathrow Terminal 5 LU
# Uxbridge Heathrow Terminal 5 LU
# Victoria LU Heathrow Terminal 5 LU
# Walthamstow Central Heathrow Terminal 5 LU
# Wanstead Heathrow Terminal 5 LU
# Warren Street Heathrow Terminal 5 LU
# Warwick Avenue Heathrow Terminal 5 LU
# Waterloo LU Heathrow Terminal 5 LU
# Watford Heathrow Terminal 5 LU
# Wembley Central Heathrow Terminal 5 LU
# Wembley Park Heathrow Terminal 5 LU
# West Acton Heathrow Terminal 5 LU
# Westbourne Park Heathrow Terminal 5 LU
# West Brompton Heathrow Terminal 5 LU
# West Finchley Heathrow Terminal 5 LU
# West Ham Heathrow Terminal 5 LU
# West Hampstead LU Heathrow Terminal 5 LU
# West Harrow Heathrow Terminal 5 LU
# West Kensington Heathrow Terminal 5 LU
# Westminster Heathrow Terminal 5 LU
# Whitechapel Heathrow Terminal 5 LU
# White City Heathrow Terminal 5 LU
# Willesden Green Heathrow Terminal 5 LU
# Willesden Junction Heathrow Terminal 5 LU
# Wimbledon Heathrow Terminal 5 LU
# Wimbledon Park Heathrow Terminal 5 LU
# Woodford Heathrow Terminal 5 LU
# Wood Green Heathrow Terminal 5 LU
# Woodside Park Heathrow Terminal 5 LU
# Hammersmith (H&C) Heathrow Terminal 5 LU
# Edgware Road (Bak) Heathrow Terminal 5 LU
# Shepherd's Bush Market Heathrow Terminal 5 LU
# Pimlico Heathrow Terminal 5 LU
# Vauxhall LU Heathrow Terminal 5 LU
# Brixton LU Heathrow Terminal 5 LU
# Hatton Cross Heathrow Terminal 5 LU
# Heathrow Terminals 123 LU Heathrow Terminal 5 LU
# Heathrow Terminal 4 LU Heathrow Terminal 5 LU
# node Heathrow Terminal 5 LU Acton Town
# node Heathrow Terminal 5 LU Barbican
# node Heathrow Terminal 5 LU Aldgate
# node Heathrow Terminal 5 LU Aldgate East
# node Heathrow Terminal 5 LU Alperton
# node Heathrow Terminal 5 LU Amersham
# node Heathrow Terminal 5 LU Angel
# node Heathrow Terminal 5 LU Archway
# node Heathrow Terminal 5 LU Arnos Grove
# node Heathrow Terminal 5 LU Arsenal
# node Heathrow Terminal 5 LU Baker Street
# node Heathrow Terminal 5 LU Balham LU
# node Heathrow Terminal 5 LU Bank and Monument
# node Heathrow Terminal 5 LU Barking
# node Heathrow Terminal 5 LU Barkingside
# node Heathrow Terminal 5 LU Barons Court
# node Heathrow Terminal 5 LU Bayswater
# node Heathrow Terminal 5 LU Becontree
# node Heathrow Terminal 5 LU Belsize Park
# node Heathrow Terminal 5 LU Bethnal Green LU
# node Heathrow Terminal 5 LU Blackfriars LU
# node Heathrow Terminal 5 LU Blackhorse Road
# node Heathrow Terminal 5 LU Bond Street
# node Heathrow Terminal 5 LU Borough
# node Heathrow Terminal 5 LU Boston Manor
# node Heathrow Terminal 5 LU Bounds Green
# node Heathrow Terminal 5 LU Bow Road
# node Heathrow Terminal 5 LU Brent Cross
# node Heathrow Terminal 5 LU Bromley-by-Bow
# node Heathrow Terminal 5 LU Buckhurst Hill
# node Heathrow Terminal 5 LU Burnt Oak
# node Heathrow Terminal 5 LU Caledonian Road
# node Heathrow Terminal 5 LU Camden Town
# node Heathrow Terminal 5 LU Cannon Street LU
# node Heathrow Terminal 5 LU Canons Park
# node Heathrow Terminal 5 LU Chalfont & Latimer
# node Heathrow Terminal 5 LU Chalk Farm
# node Heathrow Terminal 5 LU Chancery Lane
# node Heathrow Terminal 5 LU Embankment
# node Heathrow Terminal 5 LU Chesham
# node Heathrow Terminal 5 LU Chigwell
# node Heathrow Terminal 5 LU Chiswick Park
# node Heathrow Terminal 5 LU Chorleywood
# node Heathrow Terminal 5 LU Clapham Common
# node Heathrow Terminal 5 LU Clapham North
# node Heathrow Terminal 5 LU Clapham South
# node Heathrow Terminal 5 LU Cockfosters
# node Heathrow Terminal 5 LU Colindale
# node Heathrow Terminal 5 LU Colliers Wood
# node Heathrow Terminal 5 LU Covent Garden
# node Heathrow Terminal 5 LU Dagenham East
# node Heathrow Terminal 5 LU Dagenham Heathway
# node Heathrow Terminal 5 LU Debden
# node Heathrow Terminal 5 LU Dollis Hill
# node Heathrow Terminal 5 LU Ealing Broadway
# node Heathrow Terminal 5 LU Ealing Common
# node Heathrow Terminal 5 LU Earl's Court
# node Heathrow Terminal 5 LU East Acton
# node Heathrow Terminal 5 LU Eastcote
# node Heathrow Terminal 5 LU East Finchley
# node Heathrow Terminal 5 LU East Ham
# node Heathrow Terminal 5 LU East Putney
# node Heathrow Terminal 5 LU Edgware
# node Heathrow Terminal 5 LU Edgware Road (DIS)
# node Heathrow Terminal 5 LU Elephant & Castle LU
# node Heathrow Terminal 5 LU Elm Park
# node Heathrow Terminal 5 LU Epping
# node Heathrow Terminal 5 LU Euston LU
# node Heathrow Terminal 5 LU Euston Square
# node Heathrow Terminal 5 LU Fairlop
# node Heathrow Terminal 5 LU Farringdon
# node Heathrow Terminal 5 LU Finchley Central
# node Heathrow Terminal 5 LU Finchley Road
# node Heathrow Terminal 5 LU Finsbury Park LU
# node Heathrow Terminal 5 LU Fulham Broadway
# node Heathrow Terminal 5 LU Gants Hill
# node Heathrow Terminal 5 LU Gloucester Road
# node Heathrow Terminal 5 LU Golders Green
# node Heathrow Terminal 5 LU Goldhawk Road
# node Heathrow Terminal 5 LU Goodge Street
# node Heathrow Terminal 5 LU Grange Hill
# node Heathrow Terminal 5 LU Great Portland Street
# node Heathrow Terminal 5 LU Greenford
# node Heathrow Terminal 5 LU Green Park
# node Heathrow Terminal 5 LU Gunnersbury
# node Heathrow Terminal 5 LU Hainault
# node Heathrow Terminal 5 LU Hammersmith (DIS)
# node Heathrow Terminal 5 LU Hampstead
# node Heathrow Terminal 5 LU Hanger Lane
# node Heathrow Terminal 5 LU Harlesden
# node Heathrow Terminal 5 LU Harrow & Wealdstone
# node Heathrow Terminal 5 LU Harrow-on-the-Hill
# node Heathrow Terminal 5 LU Wood Lane
# node Heathrow Terminal 5 LU Hendon Central
# node Heathrow Terminal 5 LU High Barnet
# node Heathrow Terminal 5 LU Highbury & Islington
# node Heathrow Terminal 5 LU Highgate
# node Heathrow Terminal 5 LU High Street Kensington
# node Heathrow Terminal 5 LU Hillingdon
# node Heathrow Terminal 5 LU Holborn
# node Heathrow Terminal 5 LU Holland Park
# node Heathrow Terminal 5 LU Holloway Road
# node Heathrow Terminal 5 LU Hornchurch
# node Heathrow Terminal 5 LU Hounslow Central
# node Heathrow Terminal 5 LU Hounslow East
# node Heathrow Terminal 5 LU Hounslow West
# node Heathrow Terminal 5 LU Hyde Park Corner
# node Heathrow Terminal 5 LU Ickenham
# node Heathrow Terminal 5 LU Kennington
# node Heathrow Terminal 5 LU Kensal Green
# node Heathrow Terminal 5 LU Kensington (Olympia)
# node Heathrow Terminal 5 LU Kentish Town
# node Heathrow Terminal 5 LU Kenton
# node Heathrow Terminal 5 LU Kew Gardens
# node Heathrow Terminal 5 LU Kilburn
# node Heathrow Terminal 5 LU Kilburn Park
# node Heathrow Terminal 5 LU Kingsbury
# node Heathrow Terminal 5 LU King's Cross St. Pancras
# node Heathrow Terminal 5 LU Knightsbridge
# node Heathrow Terminal 5 LU Ladbroke Grove
# node Heathrow Terminal 5 LU Lambeth North
# node Heathrow Terminal 5 LU Lancaster Gate
# node Heathrow Terminal 5 LULatimer Road
# node Heathrow Terminal 5 LU Leicester Square
# node Heathrow Terminal 5 LU Leyton
# node Heathrow Terminal 5 LU Leytonstone
# node Heathrow Terminal 5 LU Liverpool Street LU
# node Heathrow Terminal 5 LU London Bridge LU
# node Heathrow Terminal 5 LU Loughton
# node Heathrow Terminal 5 LU Maida Vale
# node Heathrow Terminal 5 LU Manor House
# node Heathrow Terminal 5 LU Mansion House
# node Heathrow Terminal 5 LU Marble Arch
# node Heathrow Terminal 5 LU Marylebone LU
# node Heathrow Terminal 5 LU Mile End
# node Heathrow Terminal 5 LU Mill Hill East
# node Heathrow Terminal 5 LU Moorgate
# node Heathrow Terminal 5 LU Morden
# node Heathrow Terminal 5 LU Mornington Crescent
# node Heathrow Terminal 5 LU Neasden
# node Heathrow Terminal 5 LU Newbury Park
# node Heathrow Terminal 5 LU North Acton
# node Heathrow Terminal 5 LU North Ealing
# node Heathrow Terminal 5 LU Northfields
# node Heathrow Terminal 5 LU Northolt
# node Heathrow Terminal 5 LU North Wembley
# node Heathrow Terminal 5 LU Northwick Park
# node Heathrow Terminal 5 LU Northwood
# node Heathrow Terminal 5 LU Northwood Hills
# node Heathrow Terminal 5 LU Notting Hill Gate
# node Heathrow Terminal 5 LU Oakwood
# node Heathrow Terminal 5 LU Old Street
# node Heathrow Terminal 5 LU Osterley
# node Heathrow Terminal 5 LU Oval
# node Heathrow Terminal 5 LU Oxford Circus
# node Heathrow Terminal 5 LU Paddington TfL
# node Heathrow Terminal 5 LU Park Royal
# node Heathrow Terminal 5 LU Parsons Green
# node Heathrow Terminal 5 LU Perivale
# node Heathrow Terminal 5 LU Piccadilly Circus
# node Heathrow Terminal 5 LU Pinner
# node Heathrow Terminal 5 LU Plaistow
# node Heathrow Terminal 5 LU Preston Road
# node Heathrow Terminal 5 LU Putney Bridge
# node Heathrow Terminal 5 LU Queensbury
# node Heathrow Terminal 5 LU Queen's Park
# node Heathrow Terminal 5 LU Queensway
# node Heathrow Terminal 5 LU Ravenscourt Park
# node Heathrow Terminal 5 LU Rayners Lane
# node Heathrow Terminal 5 LU Redbridge
# node Heathrow Terminal 5 LU Regent's Park
# node Heathrow Terminal 5 LU Richmond
# node Heathrow Terminal 5 LU Rickmansworth
# node Heathrow Terminal 5 LU Royal Oak
# node Heathrow Terminal 5 LU Ruislip
# node Heathrow Terminal 5 LU Ruislip Gardens
# node Heathrow Terminal 5 LU Ruislip Manor
# node Heathrow Terminal 5 LU Russell Square
# node Heathrow Terminal 5 LU St. James's Park
# node Heathrow Terminal 5 LU St. John's Wood
# node Heathrow Terminal 5 LU St. Paul's
# node Heathrow Terminal 5 LU Seven Sisters
# node Heathrow Terminal 5 LU Shepherd's Bush LU
# node Heathrow Terminal 5 LU Sloane Square
# node Heathrow Terminal 5 LU Snaresbrook
# node Heathrow Terminal 5 LU South Ealing
# node Heathrow Terminal 5 LU Southfields
# node Heathrow Terminal 5 LU Southgate
# node Heathrow Terminal 5 LU South Harrow
# node Heathrow Terminal 5 LU South Kensington
# node Heathrow Terminal 5 LU South Ruislip
# node Heathrow Terminal 5 LU South Wimbledon
# node Heathrow Terminal 5 LU South Woodford
# node Heathrow Terminal 5 LU Stamford Brook
# node Heathrow Terminal 5 LU Stanmore
# node Heathrow Terminal 5 LU Stepney Green
# node Heathrow Terminal 5 LU Stockwell
# node Heathrow Terminal 5 LU Stonebridge Park
# node Heathrow Terminal 5 LU Charing Cross LU
# node Heathrow Terminal 5 LU Stratford
# node Heathrow Terminal 5 LU Sudbury Hill
# node Heathrow Terminal 5 LU Sudbury Town
# node Heathrow Terminal 5 LU Swiss Cottage
# node Heathrow Terminal 5 LU Temple
# node Heathrow Terminal 5 LU Theydon Bois
# node Heathrow Terminal 5 LU Tooting Bec
# node Heathrow Terminal 5 LU Tooting Broadway
# node Heathrow Terminal 5 LU Tottenham Court Road
# node Heathrow Terminal 5 LU Tottenham Hale LU
# node Heathrow Terminal 5 LU Totteridge & Whetstone
# node Heathrow Terminal 5 LU Tower Hill
# node Heathrow Terminal 5 LU Tufnell Park
# node Heathrow Terminal 5 LU Turnham Green
# node Heathrow Terminal 5 LU Turnpike Lane
# node Heathrow Terminal 5 LU Upminster
# node Heathrow Terminal 5 LU Upminster Bridge
# node Heathrow Terminal 5 LU Upney
# node Heathrow Terminal 5 LU Upton Park
# node Heathrow Terminal 5 LU Uxbridge
# node Heathrow Terminal 5 LU Victoria LU
# node Heathrow Terminal 5 LU Walthamstow Central
# node Heathrow Terminal 5 LU Wanstead
# node Heathrow Terminal 5 LU Warren Street
# node Heathrow Terminal 5 LU Warwick Avenue
# node Heathrow Terminal 5 LU Waterloo LU
# node Heathrow Terminal 5 LU Watford
# node Heathrow Terminal 5 LU Wembley Central
# node Heathrow Terminal 5 LU Wembley Park
# node Heathrow Terminal 5 LU West Acton
# node Heathrow Terminal 5 LU Westbourne Park
# node Heathrow Terminal 5 LU West Brompton
# node Heathrow Terminal 5 LU West Finchley
# node Heathrow Terminal 5 LU West Ham
# node Heathrow Terminal 5 LU West Hampstead LU
# node Heathrow Terminal 5 LU West Harrow
# node Heathrow Terminal 5 LU West Kensington
# node Heathrow Terminal 5 LU Westminster
# node Heathrow Terminal 5 LU West Ruislip
# node Heathrow Terminal 5 LU Whitechapel
# node Heathrow Terminal 5 LU White City
# node Heathrow Terminal 5 LU Willesden Green
# node Heathrow Terminal 5 LU Willesden Junction
# node Heathrow Terminal 5 LU Wimbledon
# node Heathrow Terminal 5 LU Wimbledon Park
# node Heathrow Terminal 5 LU Woodford
# node Heathrow Terminal 5 LU Wood Green
# node Heathrow Terminal 5 LU Woodside Park
# nodeHeathrow Terminal 5 LU Hammersmith (H&C)
# node Heathrow Terminal 5 LU Edgware Road (Bak)
# node Heathrow Terminal 5 LU Shepherd's Bush Market
# node Heathrow Terminal 5 LU Pimlico
# node Heathrow Terminal 5 LU Vauxhall LU
# node Heathrow Terminal 5 LU Brixton LU
# node Heathrow Terminal 5 LU Hatton Cross
# node Heathrow Terminal 5 LU Heathrow Terminals 123 LU
# node Heathrow Terminal 5 LU Heathrow Terminal 4 LU
# node Heathrow Terminal 5 LU Southwark
# node Heathrow Terminal 5 LU Bermondsey
# node Heathrow Terminal 5 LU Canada Water
# node Heathrow Terminal 5 LU North Greenwich
# node Heathrow Terminal 5 LU Canary Wharf LU
# node Heathrow Terminal 5 LU Canning Town
# Southwark Heathrow Terminal 5 LU
# Bermondsey Heathrow Terminal 5 LU
# Canada Water Heathrow Terminal 5 LU
# North Greenwich Heathrow Terminal 5 LU
# Canary Wharf LU Heathrow Terminal 5 LU
# Canning Town Heathrow Terminal 5 LU

# %%
baseshortest = fl.load_obj('baseshortest')

# %%
#TODO remove prints ('no new path..')
for edge in graph.edges():
    name = ",".join(edge)
    if edge == ('Bromley-by-Bow', 'West Ham'): 
        print('yes')
        shortest_paths = scr.update_shortest_paths(graph, edge, baseshortest)
        fl.save_obj(shortest_paths, name, 'shortest/')
# Out:
# yes

# %% [markdown]
# TODO: add basemodel

# %% [markdown]
# Creating the networkx models, assigning passengers and travel time

# %%
for i in range(5): #graph.edges():
    edge = list(graph.edges())[i]
    name = ",".join(edge)
    tempshortest = fl.load_obj(name, 'shortest/')
    tempgraphs = scr.n1_analysis(basegraphs, od, tempshortest, edge)
    fl.save_obj(tempgraphs, name, 'n1graphs/')
    print('added for edge: {}'.format(name))

# %% [markdown]
# Grabbing travel time and amount of passengers traveling over link, creating pandas series object

# %% [markdown]
# SECOND ITERATION

# %% [markdown]
# Create base estimate for passengers:

# %%
basegraphs = fl.load_obj('basegraphs')
od = fl.get_OD_LU()
baseshortest = fl.load_obj('baseshortest')
tempgraphs, passengers = scr.n1_analysis(basegraphs, od, baseshortest, None)
fl.save_obj(tempgraphs, 'basepassengers')
fl.save_obj(passengers, 'base', 'passengers/')
# Out:
# None
# Added passengers for timeslot: Morning (0500-0700), total rows: 68545
# Added passengers for timeslot: AM Peak (0700-1000), total rows: 68545
# Added passengers for timeslot: Inter Peak (1000-1600), total rows: 68545
# Added passengers for timeslot: PM Peak (1600-1900), total rows: 68545
# Added passengers for timeslot: Evening (1900-2200), total rows: 68545
# Added passengers for timeslot: Late (2200-0030), total rows: 68545
# Added passengers for timeslot: Night (0030-0300), total rows: 68545
# Added passengers for timeslot: Early (0300-0500), total rows: 68545

# %% [markdown]
# Capacity needs to be fixed in order to give insights in the capacity utilization of the network:

# %%
basegraphs = fl.load_obj('basepassengers')

def fixCapacity(bgraph, depth):
    depth += 1
    nocap = [(a, b) for a, b, data in bgraph.edges(data=True) if data['capacity'] == 0]
    for start, end in nocap:
        sneighbors = [n for n in bgraph.neighbors(start)]
        eneighbors = [n for n in bgraph.neighbors(end)]
        savg = sum([bgraph[s][start]['capacity'] for s in sneighbors])/len(sneighbors) #average of neighbours at start of link
        eavg = sum([bgraph[e][end]['capacity'] for e in eneighbors])/len(sneighbors) #average of neighbours at end of link
        bgraph[start][end]['capacity'] = (savg + eavg)//2
    if depth > 100: #it might not find a solution, then stop
        print('no solution found')
        return
    if len(nocap) > 0: fixCapacity(bgraph, depth)
for bgraph in basegraphs.values(): 
    fixCapacity(bgraph, 0)
fl.save_obj(basegraphs, 'basepassfixed')
# Out:
# no solution found

# %% [markdown]
# AWS STUFF:

# %%
import os.path
from os import path
import networkx as nx
import scripts2 as scr
import fileloader as fl
import dataframes as df
import time

graph = fl.get_network()
basegraphs = fl.load_obj('basegraphs')
od = fl.get_OD_LU()
for i len(list(graph.edges()))//2):
    starttime = time.time()
    #i+= len(list(graph.edges()))//2 #I ended up creating 2 aws.py files, one starting halway down, this way my computing power was better optimised (redneck multithreading)
    edge = list(graph.edges())[i]
    name = ",".join(edge)
    if path.exists('Pickles/test/'+ name + '.pickle'): continue #if I already created this file, skip 
    tempshortest = fl.load_obj(name, 'shortest/')
    tempgraphs, passengers = scr.n1_analysis(basegraphs, od, tempshortest, edge)
    fl.save_obj(tempgraphs, name, 'awsgraphs/')
    fl.save_obj(passengers, name, 'passengers/')
    print('added for edge: {}, time taken {}'.format(name, starttime-time.time()))
